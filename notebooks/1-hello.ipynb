# %%
print("Hello Jiten here :)")
# Out:
# Hello Jiten here :)

# %%
# !uv pip freeze
# Out:
# Using Python 3.13.2 environment at: /Users/hi/jitenStuff/MyGit/LangDjangoAIX/.venv
# aiohappyeyeballs==2.6.1
# aiohttp==3.12.13
# aiosignal==1.3.2
# annotated-types==0.7.0
# anyio==4.9.0
# appnope==0.1.4
# argon2-cffi==25.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asgiref==3.8.1
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# babel==2.17.0
# beautifulsoup4==4.13.4
# bleach==6.2.0
# certifi==2025.6.15
# cffi==1.17.1
# charset-normalizer==3.4.2
# comm==0.2.2
# debugpy==1.8.14
# decorator==5.2.1
# defusedxml==0.7.1
# distro==1.9.0
# django==5.2.3
# dnspython==2.7.0
# email-validator==2.2.0
# executing==2.2.0
# fastjsonschema==2.21.1
# fqdn==1.5.1
# frozenlist==1.7.0
# h11==0.16.0
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.10
# ipykernel==6.29.5
# ipython==9.3.0
# ipython-pygments-lexers==1.1.1
# ipywidgets==8.1.7
# isoduration==20.11.0
# jedi==0.19.2
# jinja2==3.1.6
# jiter==0.10.0
# json5==0.12.0
# jsonpatch==1.33
# jsonpointer==3.0.0
# jsonschema==4.24.0
# ...
